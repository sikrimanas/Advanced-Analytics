# %%
import pandas as pd

# %%
df = pd.read_csv('/home/ischool/Downloads/UNdata_Export_20161110_211248464.csv')

# %%
df.head()
# Out:
#   Country or territory of asylum or residence Country or territory of origin  \
# 0                                 Afghanistan                           Iraq
# 1                                 Afghanistan           Islamic Rep. of Iran
# 2                                 Afghanistan                       Pakistan
# 3                                 Afghanistan             State of Palestine
# 4                                     Albania                        Algeria
#
#      Year  Refugees<sup>*</sup>  Refugees assisted by UNHCR  \
# 0  2013.0                   1.0                         1.0
# 1  2013.0                  36.0                        36.0
# 2  2013.0                  34.0                        34.0
# 3  2013.0                   1.0                         1.0
# 4  2013.0                   0.0                         0.0
#
#    Total refugees and people in refugee-like situations<sup>**</sup>  \
# 0                                                1.0
# ...

# %%
df.describe()
# Out:
# /usr/local/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                Year  Refugees<sup>*</sup>  Refugees assisted by UNHCR  \
# count  80428.000000          8.033800e+04                3.626600e+04
# mean    2003.670339          5.327982e+03                2.363207e+03
# std        7.303549          6.399736e+04                3.699795e+04
# min     1975.000000          0.000000e+00                0.000000e+00
# 25%             NaN                   NaN                         NaN
# 50%             NaN                   NaN                         NaN
# 75%             NaN                   NaN                         NaN
# max     2013.000000          3.272290e+06                1.899842e+06
#
#        Total refugees and people in refugee-like situations<sup>**</sup>  \
# count                                       8.038900e+04
# ...

# %%
# Group data based on country of origin
grouped_data = df.groupby(['Country or territory of origin'])

# %%
# Descriptive statistics on refugees assisted by UN categorized by country of origin
grouped_data['Refugees assisted by UNHCR'].describe().unstack()
# Out:
# /usr/local/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                                                     count          mean  \
# Country or territory of origin
# Afghanistan                                         787.0  43607.231258
# Albania                                             181.0      2.060773
# Algeria                                             475.0      4.850526
# Andorra                                              10.0      0.000000
# Angola                                              554.0   2409.371841
# Antigua and Barbuda                                  16.0      0.000000
# Argentina                                            91.0      1.714286
# Armenia                                             286.0     37.783217
# Aruba                                                 1.0      0.000000
# ...

# %%
grouped_data['Refugees<sup>*</sup>'].describe().unstack()
# Out:
# /usr/local/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                                                      count          mean  \
# Country or territory of origin
# Afghanistan                                         1472.0  79976.161005
# Albania                                              542.0    429.311808
# Algeria                                              958.0    165.123173
# Andorra                                               42.0      2.404762
# Angola                                              1119.0  11600.788204
# Antigua and Barbuda                                   35.0      8.400000
# Argentina                                            254.0     55.570866
# Armenia                                              674.0   2654.483680
# Aruba                                                  1.0      0.000000
# ...

# %%
clean_df = df.dropna(subset = ['Year','Refugees<sup>*</sup>','Refugees assisted by UNHCR','Total refugees and people in refugee-like situations<sup>**</sup>','Total refugees and people in refugee-like situations assisted by UNHCR'])

# %%
grouped_data2 = clean_df.groupby(['Country or territory of origin','Year'])

# %%
grouped_data2['Refugees assisted by UNHCR'].describe().unstack()
# Out:
#                                        count          mean            std  \
# Country or territory of origin Year
# Afghanistan                    1999.0   29.0  87752.275862  325929.676702
#                                2000.0   37.0  73398.918919  309000.115589
#                                2001.0   43.0  70355.930233  318516.010379
#                                2002.0   45.0  52343.266667  243186.967981
#                                2003.0   46.0  43036.369565  204082.348764
#                                2004.0   42.0  45977.523810  206056.576640
#                                2005.0   39.0  51809.128205  224650.655398
#                                2006.0   38.0  51946.000000  221989.179236
#                                2007.0   42.0  43084.833333  193130.007090
#                                2008.0   37.0  46436.621622  195843.125788
#                                2009.0   59.0  30505.711864  164325.913555
# ...

# %%
import matplotlib.pyplot as plt
import pandas
import numpycorrelations = grouped_data2.corr()
# plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()
